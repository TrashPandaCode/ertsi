# %%
import numpy as np
import sounddevice as sd
import scipy.signal as signal
import matplotlib.pyplot as plt
import pyroomacoustics as pra
from scipy.io import wavfile
import csv
from datetime import datetime
import os

# %%
ir = wavfile.read("C:/Users/Leo/Downloads/impulse_response_20250428_161423.wav")
ir2 = wavfile.read("recordings/leo/20250428_161423/impulse_response_20250428_161423.wav")

# %%
rt60_band = pra.experimental.measure_rt60(ir[1], 48000, plot=True)
rt60_band
# Out:
# np.float64(3.0912916666666663)
